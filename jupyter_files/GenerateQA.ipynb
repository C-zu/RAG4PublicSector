# %%
# !pip install colab-xterm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 2.7 MB/s eta 0:00:00
# ...

# %%
# %load_ext colabxterm

# %%
! pip install unstructured langchain langchain_community autorag sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.7/987.7 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.4/144.4 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 19.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.0/372.0 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install llama-index

# %%
# !pip install llama_index-llms-gemini llama_index-llms-cohere
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 2.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.4.0 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3815/1408506528.py in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import TokenTextSplitter
from autorag.data.corpus import llama_text_node_to_parquet

documents = SimpleDirectoryReader('./drive/MyDrive/txt_file').load_data()
nodes = TokenTextSplitter().get_nodes_from_documents(documents=documents, chunk_size=10000, chunk_overlap=1000)
corpus_df = llama_text_node_to_parquet(documents, './corpus.parquet')

# %%
import pandas as pd
corpus_df = pd.read_parquet("corpus.parquet")

# %%
corpus_df_temp = corpus_df[2600:]

# %%
from autorag.data.qacreation import generate_qa_llama_index, make_single_content_qa
from llama_index.llms.ollama import Ollama
from llama_index.llms.huggingface import HuggingFaceLLM
import os
from llama_index.llms.gemini import Gemini
from google.generativeai.types.safety_types import HarmBlockThreshold, HarmCategory

# safety_settings = {
#             HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
#             HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
#             HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
#             HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
#         }
llm = Gemini(model="models/gemini-1.5-flash",api_key="AIzaSyC-k9cJloXSFEyF87jBvtshE5F1dNqXfEc",temperature=0)
# llm = Cohere(model="command-r-plus",api_key="zYWa095uMjrkvI1OiGAamgh9g8yVe57b07X9MQd2")
# Out:
# 2024-07-18 04:33:42.586464: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-18 04:33:42.586595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-18 04:33:42.598050: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-18 04:33:42.633868: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
prompt = """
Bạn là một AI được giao nhiệm vụ chuyển đổi Văn bản về thủ tục dịch vụ công thành bộ câu hỏi và trả lời.
Bao quát càng nhiều chi tiết từ Văn bản càng tốt trong bộ Hỏi đáp.

Hướng dẫn:

Cả câu hỏi và câu trả lời PHẢI ĐƯỢC trích xuất từ Văn bản đã cho.
Câu trả lời phải là câu hoàn chỉnh.
Câu hỏi nên chi tiết nhất, đa dạng nhất (có thể sử dụng các từ đồng nghĩa NHƯNG TRỪ tên thủ tục) có thể từ Văn bản, và câu hỏi luôn phải bao gồm một thủ tục cụ thể tránh mơ hồ như văn bản này, thủ tục này.
Kết quả phải luôn có số lượng câu hỏi và câu trả lời được cung cấp.
Tạo câu hỏi hỏi về thông tin từ Văn bản.
PHẢI bao gồm các từ khóa cụ thể từ Văn bản.
Không được đề cập đến bất kỳ điều nào sau đây trong câu hỏi: "trong văn bản đã cho", "trong thông tin đã cung cấp", "thủ tục nào trong văn bản", "trong văn bản trên", "thủ tục trên", "Thủ tục hành chính nào", "Thủ tục này" v.v.
Ví dụ câu hỏi:

Owen và Riggs quen nhau như thế nào?
Từ “fore” trong golf có nghĩa là gì?
Điều gì làm cho Charging Bull ở NYC trở nên phổ biến với du khách?
Quân đội sử dụng loại súng ngắn nào?
Ai là nghệ sĩ violin vĩ đại nhất trong thời kỳ lãng mạn?

Văn bản:

Mark Hamill trong vai Luke Skywalker: Một trong những Jedi cuối cùng còn sống, được huấn luyện bởi Obi-Wan và Yoda, cũng là một phi công X-wing có kỹ năng và liên minh với phiến quân.
Harrison Ford trong vai Han Solo: Một tay buôn lậu vô lại, giúp đỡ phiến quân chống lại Đế chế. Han là bạn của Luke và Leia, cũng như là người yêu của Leia.
Carrie Fisher trong vai Leia Organa: Công chúa cũ của hành tinh Alderaan bị phá hủy, người gia nhập phiến quân; chị em song sinh của Luke, và là người yêu của Han.
Billy Dee Williams trong vai Lando Calrissian: Quản trị viên cũ của Thành phố Mây và là một trong những người bạn của Han, giúp đỡ phiến quân.
Anthony Daniels trong vai C-3PO: Một droid giao thức hình người, theo phe phiến quân.
Peter Mayhew trong vai Chewbacca: Một Wookiee là bạn lâu năm của Han, tham gia vào phiến quân.
Kenny Baker trong vai R2-D2: Một droid astromech, được Luke mua; và là bạn lâu năm của C-3PO. Ông cũng đóng vai một droid năng lượng GONK ở hậu cảnh.
Ian McDiarmid trong vai Hoàng đế: Người cai trị tối cao ác độc sáng lập Đế chế Thiên Hà, và là sư phụ Sith của Vader.
Frank Oz trong vai Yoda: Bậc thầy Jedi khôn ngoan, hàng thế kỷ tuổi, người là thầy Jedi tự lưu vong của Luke sống trên Dagobah. Sau khi chết, ông tái hiện với Luke dưới dạng một bóng ma của Lực lượng. Puppetry của Yoda được hỗ trợ bởi Mike Quinn.
David Prowse trong vai Darth Vader / Anakin Skywalker: Một chúa tể Sith mạnh mẽ và là người đứng thứ hai trong Đế chế Thiên Hà; cha của Luke và Leia.

Kết quả với 4 câu hỏi và trả lời:

[Q]: Ai đã đóng vai cha của Luke trong "Return of the Jedi"?
[A]: David Prowse đóng vai Darth Vader, còn gọi là Anakin Skywalker, là cha của Luke và Leia.
[Q]: Ai là bạn thân nhất của Han Solo? Và anh ta thuộc loài gì?
[A]: Bạn thân nhất của Han Solo là Chewbacca, anh ta là một Wookiee.
[Q]: Ai đã đóng vai thầy giáo của Luke trong "Return of the Jedi"?
[A]: Yoda, bậc thầy Jedi khôn ngoan, hàng thế kỷ tuổi, là thầy Jedi tự lưu vong của Luke sống trên Dagobah, được đóng bởi Frank Oz. Ngoài ra, còn có đề cập đến Obi-Wan Kenobi, người đã huấn luyện Luke Skywalker, nhưng không có thông tin về ai đã đóng vai Obi-Wan Kenobi trong văn bản đã cho.
[Q]: Yoda sống ở đâu trong "Return of the Jedi"?
[A]: Yoda, bậc thầy Jedi, sống trên Dagobah.

Văn bản:

{{text}}

Kết quả với {{num_questions}} câu hỏi và trả lời:
"""

# %%
import nest_asyncio
nest_asyncio.apply()
import tracemalloc
tracemalloc.start()

# %%
qa_df_2600_2789 = make_single_content_qa(corpus_df_temp, 300, generate_qa_llama_index, llm=llm, question_num_per_content=5,
                               output_filepath='./qa.parquet', cache_batch=64,prompt=prompt,upsert=True)
# Out:
# WARNING:AutoRAG:content_size 300 is larger than the corpus size 190. Setting content_size to the corpus size.
# 0it [00:00, ?it/s]
# 0
# /usr/local/lib/python3.10/dist-packages/swifter/swifter.py:87: UserWarning: This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/swifter/swifter.py:87: UserWarning: This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/swifter/swifter.py:87: UserWarning: This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`.
#   warnings.warn(
# ...

# %%
for i, row in df.iterrows():
    if pd.notna(row['query']) and pd.notna(row['generation_gt']):
        print(f"{i} {row['query']}\n")
        print(f"{row['generation_gt'][0]}\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# 467 Cơ quan nào có thẩm quyền cấp lại giấy phép đào tạo lái xe ô tô?
#
# Cục Đường bộ Việt Nam hoặc Sở Giao thông vận tải có thẩm quyền cấp lại giấy phép đào tạo lái xe ô tô.
#
#
# 468 Thủ tục cấp lại giấy phép đào tạo lái xe ô tô thuộc lĩnh vực nào?
#
# Thủ tục cấp lại giấy phép đào tạo lái xe ô tô thuộc lĩnh vực Đường bộ.
#
#
# 469 Thủ tục "Cho phép trường trung học phổ thông hoạt động trở lại" thuộc lĩnh vực nào?
#
# Thủ tục "Cho phép trường trung học phổ thông hoạt động trở lại" thuộc lĩnh vực Giáo dục trung học.
#
#
# 470 Trường trung học phổ thông công lập cần nộp hồ sơ cho phép hoạt động giáo dục trở lại ở đâu?
#
# Trường trung học phổ thông công lập cần gửi trực tiếp hoặc qua bưu điện 01 bộ hồ sơ theo quy định đến Sở Giáo dục và Đào tạo.
#
#
# 471 Nếu hồ sơ chưa đúng quy định, Sở Giáo dục và Đào tạo sẽ làm gì?
#
# ...

# %%
qa_df_2600_2789 = qa_df_2600_2789[(qa_df_2600_2789['query'].notna()) & (qa_df_2600_2789['generation_gt'].notna())]

# %%
len(qa_df_2600_2789)
# Out:
# 940

# %%
qa_df_2600_2789.to_csv("./qa_df_2600_2789.csv",index=False)

# %%
qa_df_0_99 = pd.read_csv("qa_df_0_99.csv")
qa_df_100_399 = pd.read_csv("qa_df_100_399.csv")
qa_df_400_699 = pd.read_csv("qa_df_400_699.csv")
qa_df_700_999 = pd.read_csv("qa_df_700_999.csv")
qa_df_1000_1299 = pd.read_csv("qa_df_1000_1299.csv")
qa_df_1300_1599 = pd.read_csv("qa_df_1300_1599.csv")
qa_df_1600_1899 = pd.read_csv("qa_df_1600_1899.csv")
qa_df_1900_1899 = pd.read_csv("qa_df_1900_2199.csv")
qa_df_2200_2399 = pd.read_csv("qa_df_2200_2399.csv")
qa_df_2400_2599 = pd.read_csv("qa_df_2400_2599.csv")
qa_df_2600_2789 = pd.read_csv("qa_df_2600_2789.csv")

# %%
qa_df_100_399
# Out:
#                                     retrieval_gt  \
# 0     [['1e08e360-a3d3-4e86-b6b8-ce68f9978e5d']]
# 1     [['1e08e360-a3d3-4e86-b6b8-ce68f9978e5d']]
# 2     [['1e08e360-a3d3-4e86-b6b8-ce68f9978e5d']]
# 3     [['1e08e360-a3d3-4e86-b6b8-ce68f9978e5d']]
# 4     [['1e08e360-a3d3-4e86-b6b8-ce68f9978e5d']]
# ...                                          ...
# 1465  [['49bf6d65-aab2-451a-8e1e-ad227673fbf7']]
# 1466  [['49bf6d65-aab2-451a-8e1e-ad227673fbf7']]
# 1467  [['49bf6d65-aab2-451a-8e1e-ad227673fbf7']]
# 1468  [['49bf6d65-aab2-451a-8e1e-ad227673fbf7']]
# 1469  [['49bf6d65-aab2-451a-8e1e-ad227673fbf7']]
#
#                                        qid  \
# 0     1f736eea-b321-4007-ba10-aab53849a890
# 1     ef5ab9af-5917-45da-af56-258aa070e74f
# 2     1ba02685-d333-4e72-9bc7-7114a06dbfc8
# 3     e78e5891-9a9d-46a4-a97c-ad66950f44be
# 4     bf17a847-a9ec-434d-b002-38cf4332fc5a
# ...                                    ...
# 1465  b2200990-dce0-4a92-8dec-ddb24cdf683f
# ...

# %%
qa_df = pd.concat([
    qa_df_0_99,
    qa_df_100_399,
    qa_df_400_699,
    qa_df_700_999,
    qa_df_1000_1299,
    qa_df_1300_1599,
    qa_df_1600_1899,
    qa_df_1900_2199,
    qa_df_2200_2399,
    qa_df_2400_2599,
    qa_df_2600_2789
], ignore_index=True)

# %%
qa_df
# Out:
#                                      retrieval_gt  \
# 0      [['9f1434d6-6f62-42ab-bb08-39128d2451bd']]
# 1      [['9f1434d6-6f62-42ab-bb08-39128d2451bd']]
# 2      [['9f1434d6-6f62-42ab-bb08-39128d2451bd']]
# 3      [['9f1434d6-6f62-42ab-bb08-39128d2451bd']]
# 4      [['9f1434d6-6f62-42ab-bb08-39128d2451bd']]
# ...                                           ...
# 13640  [['fcaf74d5-92d7-4bd8-be54-6c77cad74c45']]
# 13641  [['fcaf74d5-92d7-4bd8-be54-6c77cad74c45']]
# 13642  [['fcaf74d5-92d7-4bd8-be54-6c77cad74c45']]
# 13643  [['fcaf74d5-92d7-4bd8-be54-6c77cad74c45']]
# 13644  [['fcaf74d5-92d7-4bd8-be54-6c77cad74c45']]
#
#                                         qid  \
# 0      a4b81608-8995-4b62-99d4-95acaf83a84b
# 1      53966078-9d9b-46c9-9734-7e9835518bf4
# 2      6b543e4d-6f84-4b71-8609-c15df540371d
# 3      513e59f4-b55b-44b1-9f2b-7b3be73c15b5
# 4      5e743caa-2aaa-4a61-8386-a27571c71b0d
# ...                                     ...
# 13640  8bf18abf-a159-40c0-bdab-237d6cece895
# ...

# %%
qa_df.to_csv("qa_df_2790_full.csv",index=False)

# %%
unique_queries_df = qa_df.drop_duplicates(subset=['query'])

# %%
len(unique_queries_df)
# Out:
# 12320

# %%
qa_df.to_csv("qa_df_2790_full.csv",index=False)
